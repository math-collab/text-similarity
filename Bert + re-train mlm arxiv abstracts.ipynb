# %%
## import simi

import evaluate
import pandas as pd
from sentence_transformers import evaluation, losses, models, InputExample, SentenceTransformer
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader
from transformers import AutoModelForMaskedLM, AutoTokenizer, DataCollatorForLanguageModeling, EarlyStoppingCallback, TrainingArguments, Trainer
from datasets import Dataset


TOKENIZER = AutoTokenizer.from_pretrained("bert-base-uncased", use_fast=True)
MODEL = model = AutoModelForMaskedLM.from_pretrained("bert-base-uncased")
RANDOM_STATE = 1

set_seed(RANDOM_STATE)
enable_full_determinism(RANDOM_STATE)

# %%
df = pd.read_csv("abstracts-arxiv-dataset.csv", index_col=0)
df["categories"] = df["categories"].map(lambda c: tuple(c.split()))

# %%
X = df[df["categories"].map(lambda c: len(tuple(filter(lambda s: s.startswith("math") or s.startswith("stat"), c)))>0)]
X.sample(5)
# Out:
#                                categories  doi  \
# 811596            (cs.IT, cs.NI, math.IT)  NaN
# 2106902                        (math.GR,)  NaN
# 402000                         (math.AG,)  NaN
# 1171108                        (math.CO,)  NaN
# 631241   (math.CO, cs.DM, cs.FL, math.NT)  NaN
#
#                                                       text
# 811596   Online Edge Caching in Fog-Aided Wireless Netw...
# 2106902  Virtual Endomorphisms of Nilpotent Groups. A v...
# 402000   Cancellativization of dimer models. We show th...
# 1171108  Independence number and connectivity for fract...
# 631241   Abelian Powers and Repetitions in Sturmian Wor...

# %%
X_train, X_test = train_test_split(X, train_size=0.8, random_state=RANDOM_STATE)
print("train:", len(X_train), "test:", len(X_test))
# Out:
# train: 520388 test: 130097

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0" # only use one GPU for now, see https://github.com/huggingface/transformers/issues/14128
#os.environ["TOKENIZERS_PARALLELISM"]="false"
os.environ["NNCL_DEBUG"]="INFO"

# %%
train_ds = Dataset.from_pandas(X_train[['text']].reset_index(drop=True))
test_ds = Dataset.from_pandas(X_test[['text']].reset_index(drop=True))

train_ds = train_ds.map(lambda e: TOKENIZER(e["text"], add_special_tokens=True, padding="max_length", truncation=True), batched=True)
test_ds = test_ds.map(lambda e: TOKENIZER(e["text"], add_special_tokens=True, padding="max_length", truncation=True), batched=True)
# Out:
#   0%|          | 0/521 [00:00<?, ?ba/s]
#   0%|          | 0/131 [00:00<?, ?ba/s]

# %%
targs = TrainingArguments(
        output_dir="[train]bert+re-train_mlm_abstracts_arxiv",
        overwrite_output_dir=True,
        num_train_epochs=16,
        evaluation_strategy="epoch",
        per_device_train_batch_size=16,
        per_device_eval_batch_size=16,
        save_strategy="epoch",
        load_best_model_at_end=True, 
)

trainer = Trainer(model=MODEL, args=targs,
        data_collator=DataCollatorForLanguageModeling(tokenizer=TOKENIZER, mlm=True, mlm_probability=0.15),
        train_dataset=train_ds,
        eval_dataset=test_ds,
        callbacks=[EarlyStoppingCallback(early_stopping_patience=2)],
        tokenizer=TOKENIZER
)

# %%
# %%time
# finetune model
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `BertForMaskedLM.forward` and have been ignored: text. If text are not expected by `BertForMaskedLM.forward`,  you can safely ignore this message.
# /home/christian/.local/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 520388
#   Num Epochs = 16
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 520400
#   Number of trainable parameters = 109514298
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='430101' max='520400' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [430101/520400 105:41:01 < 22:11:17, 1.13 it/s, Epoch 13.22/16]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.287600</td>
#       <td>1.213094</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.189800</td>
#       <td>1.135788</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.145300</td>
#       <td>1.086769</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.123100</td>
#       <td>1.052933</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.082500</td>
#       <td>1.031378</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.047600</td>
#       <td>1.007961</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.023400</td>
#       <td>0.986121</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.004800</td>
#       <td>0.971506</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.991200</td>
#       <td>0.954906</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.971000</td>
#       <td>0.941756</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.947000</td>
#       <td>0.930291</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.924900</td>
#       <td>0.913367</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.931700</td>
#       <td>0.900245</td>
#     </tr>
#   </tbody>
# </table><p>
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# The following columns in the evaluation set don't have a corresponding argument in `BertForMaskedLM.forward` and have been ignored: text. If text are not expected by `BertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 130097
#   Batch size = 16
# Saving model checkpoint to [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-65050
# Configuration saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-65050/config.json
# Model weights saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-65050/pytorch_model.bin
# tokenizer config file saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-65050/tokenizer_config.json
# Special tokens file saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-65050/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForMaskedLM.forward` and have been ignored: text. If text are not expected by `BertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 130097
#   Batch size = 16
# Saving model checkpoint to [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-97575
# Configuration saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-97575/config.json
# Model weights saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-97575/pytorch_model.bin
# tokenizer config file saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-97575/tokenizer_config.json
# Special tokens file saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-97575/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForMaskedLM.forward` and have been ignored: text. If text are not expected by `BertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 130097
#   Batch size = 16
# Saving model checkpoint to [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-162625
# Configuration saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-162625/config.json
# Model weights saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-162625/pytorch_model.bin
# tokenizer config file saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-162625/tokenizer_config.json
# Special tokens file saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-162625/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForMaskedLM.forward` and have been ignored: text. If text are not expected by `BertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 130097
#   Batch size = 16
# Saving model checkpoint to [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-195150
# Configuration saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-195150/config.json
# Model weights saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-195150/pytorch_model.bin
# tokenizer config file saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-195150/tokenizer_config.json
# Special tokens file saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-195150/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForMaskedLM.forward` and have been ignored: text. If text are not expected by `BertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 130097
#   Batch size = 16
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# The following columns in the evaluation set don't have a corresponding argument in `BertForMaskedLM.forward` and have been ignored: text. If text are not expected by `BertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 130097
#   Batch size = 16
# Saving model checkpoint to [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-260200
# Configuration saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-260200/config.json
# Model weights saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-260200/pytorch_model.bin
# tokenizer config file saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-260200/tokenizer_config.json
# Special tokens file saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-260200/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForMaskedLM.forward` and have been ignored: text. If text are not expected by `BertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 130097
#   Batch size = 16
# Saving model checkpoint to [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-292725
# Configuration saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-292725/config.json
# Model weights saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-292725/pytorch_model.bin
# tokenizer config file saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-292725/tokenizer_config.json
# Special tokens file saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-292725/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForMaskedLM.forward` and have been ignored: text. If text are not expected by `BertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 130097
#   Batch size = 16
# Saving model checkpoint to [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-325250
# Configuration saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-325250/config.json
# Model weights saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-325250/pytorch_model.bin
# tokenizer config file saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-325250/tokenizer_config.json
# Special tokens file saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-325250/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForMaskedLM.forward` and have been ignored: text. If text are not expected by `BertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 130097
#   Batch size = 16
# Saving model checkpoint to [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-357775
# Configuration saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-357775/config.json
# Model weights saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-357775/pytorch_model.bin
# tokenizer config file saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-357775/tokenizer_config.json
# Special tokens file saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-357775/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForMaskedLM.forward` and have been ignored: text. If text are not expected by `BertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 130097
#   Batch size = 16
# Saving model checkpoint to [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-390300
# Configuration saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-390300/config.json
# Model weights saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-390300/pytorch_model.bin
# tokenizer config file saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-390300/tokenizer_config.json
# Special tokens file saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-390300/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForMaskedLM.forward` and have been ignored: text. If text are not expected by `BertForMaskedLM.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 130097
#   Batch size = 16
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# Saving model checkpoint to [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-422825
# Configuration saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-422825/config.json
# Model weights saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-422825/pytorch_model.bin
# tokenizer config file saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-422825/tokenizer_config.json
# Special tokens file saved in [train]bert+re-train_mlm_abstracts_arxiv/checkpoint-422825/special_tokens_map.json

# %%
trainer.save_model("bert+re-train_mlm_abstracts_arxiv")
