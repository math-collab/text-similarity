# %%
import simi

import pandas as pd
from sentence_transformers import evaluation, losses, models, InputExample, SentenceTransformer
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader

MODEL = SentenceTransformer('all-mpnet-base-v2')

RANDOM_STATE = 1

def similarity_scoring(df, model, append=False):
    scores = df.apply(lambda r: simi.pairwise_cosine_similarity(simi.model_embeddings(model, [r["title_a"], r["title_b"]]))[0][0], axis=1)
    scores = pd.Series(scores, index=df.index, name="cosine-sim")
    if append:
        return df.merge(scores.to_frame(), left_index=True, right_index=True)
    return scores
# Out:
# 2024-01-10 12:52:28.359300: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
df = pd.read_csv("class-zbmath-dataset.csv", index_col=0)
df["label"] = df["label"].astype("float")
df.sample(5)
# Out:
#                                                   title_a  MSC_a  \
# 293106    Optimal risk allocation in reinsurance networks  91B30
# 225724  Total acyclicity for complexes of representati...  16G20
# 62323   Linear optimal control of time delay systems v...  49J15
# 355805                                    On \(\zeta(3)\)  11M06
# 73181   Approximation algorithms for max-bisection on ...  68R10
#
#                                       MSC2_a  \
# 293106                            ('60E15',)
# 225724  ('18E30', '16G10', '18A40', '55U35')
# 62323                     ('49N05', '90C20')
# 355805                            ('11M36',)
# 73181                             ('68W25',)
#
#                                                   title_b  MSC_b  \
# 293106  Belief-weighted Nash aggregation of Savage pre...  91B14
# 225724  Root vectors of the composition algebra of the...  16G20
# 62323             Linear optimal control problem in plane  49J15
# 355805  On a mollifier of the perturbed Riemann zeta-f...  11M06
# 73181   Deeper local search for better approximation o...  68R10
#
#                              MSC2_b  label
# 293106                   ('91B08',)    0.0
# 225724  ('17B37', '16G10', '16G70')    1.0
# 62323            ('49K15', '49N05')    1.0
# 355805           ('11M36', '11N64')    1.0
# 73181            ('05C85', '68W25')    1.0

# %%
X_treval, X_test = train_test_split(df, train_size=0.9, random_state=RANDOM_STATE)
X_train, X_eval = train_test_split(X_treval, train_size=0.888889, random_state=RANDOM_STATE)
print("train:", len(X_train), "eval:", len(X_eval), "test:", len(X_test))
# Out:
# train: 351472 eval: 43935 test: 43935

# %%
# prepare evaluation data
eval_examples = X_eval.reset_index(drop=True).apply(lambda r: InputExample(texts=[r["title_a"], r["title_b"]], label=r["label"]), axis=1)
evaluator = evaluation.EmbeddingSimilarityEvaluator.from_input_examples(eval_examples)

# %%
# prepare re-training: training data, loss
retrain_examples = X_train.reset_index(drop=True).apply(lambda r: InputExample(texts=[r["title_a"], r["title_b"]], label=r["label"]), axis=1)
retrain_dataloader = DataLoader(retrain_examples, shuffle=True, batch_size=16)
#retrain_loss = losses.SoftmaxLoss(model=MODEL, num_labels=2,
#        sentence_embedding_dimension=MODEL.get_sentence_embedding_dimension())
#retrain_loss = losses.ContrastiveLoss(model=MODEL)
retrain_loss = losses.CosineSimilarityLoss(model=MODEL)

# %%
# %%time
# finetune model
MODEL.fit(train_objectives=[(retrain_dataloader, retrain_loss)], evaluator=evaluator, epochs=10,
        output_path="sbert+retrain_class_zbmath")
# Out:
# Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/21967 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/21967 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/21967 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/21967 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/21967 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/21967 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/21967 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/21967 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/21967 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/21967 [00:00<?, ?it/s]
# CPU times: user 21h 24min 55s, sys: 1h 7s, total: 22h 25min 2s
# Wall time: 6h 25min 57s

# %%
# %%time
# evaluate Spearman-Pearson-rank-coefficient on test data
spear_ranc = MODEL.evaluate(evaluator)
spear_ranc
# Out:
# CPU times: user 9min 56s, sys: 36.5 s, total: 10min 33s
# Wall time: 1min 30s
# 0.5719917817109932

# %%
# %%time
X_test_score = similarity_scoring(X_test, MODEL, append=True)
# Out:
# CPU times: user 12min 54s, sys: 23 s, total: 13min 17s
# Wall time: 8min 12s

# %%
pd.set_option('display.max_colwidth', 160)

# %%
X_test_score.sample(15, random_state=RANDOM_STATE)
# Out:
#                                                                                                 title_a  \
# 15960                          Global exact quadratization of continuous-time nonlinear control systems
# 186573                                                  Edge operators with conditions of Toeplitz type
# 181977                                                   1-cohomology and splitting of group extensions
# 299961                                             Reputation in the long-run with imperfect monitoring
# 226982                                         Traces and quasi-traces on the Boutet de Monvel algebra.
# 306772                A cyclic weight algorithm of decoding the \((47, 24, 11)\) quadratic residue code
# 205892       Properties of the Székely-Móri symmetry criterion statistics in the case of binary vectors
# 218358                    Simultaneous visibility representations of plane \(st\)-graphs using L-shapes
# 77078                                         The unsteady MHD boundary-layer flow on a shrinking sheet
# 63150                                                                On unified contact metric manifold
# 422297                                                    On a Waring-Goldbach problem for mixed powers
# 156367                           Thermomagnetic power and figure of merit for spin-1/2 Heisenberg chain
# 276046                            Quantization of reductive Lie algebras: Construction and universality
# 336155  Numerical solution of two-dimensional time fractional cable equation with Mittag-Leffler kernel
# 124871                                     Discrete functions with a given range and a given C-spectrum
#
#         MSC_a                                                  MSC2_a  \
# 15960   93C10  ('93C15', '93A10', '34H05', '34H99', '34A34', '53A04')
# 186573  58J40           ('35S15', '47G30', '35A17', '35J70', '58J32')
# 181977  20E22                                      ('20J99', '20E07')
# 299961  91A20                                              ('91A05',)
# 226982  58J42                                              ('35S15',)
# 306772  94B35                                              ('94B40',)
# 205892  60E05                                      ('62E20', '62H10')
# 218358  05C62                             ('05C10', '05C85', '68R10')
# 77078   76W05                                      ('76N20', '76M45')
# 63150   53C15                                              ('53C25',)
# 422297  11P32                                      ('11P05', '11N36')
# 156367  82D40                                              ('82-04',)
# 276046  17B37                                              ('16W30',)
# 336155  65M70                                              ('35R11',)
# 124871  03B50                                              ('05A15',)
#
#                                                                                                   title_b  \
# 15960                    Mixed \(\mathcal{H}_2/\mathcal{H}_\infty\) control of hidden Markov jump systems
# 186573                                              A Bismut type theorem for subelliptic heat semigroups
# 181977                                                               On some products of nilpotent groups
# 299961                          Parallel repetition via fortification: analytic view and the quantum case
# 226982  The local and global parts of the basic zeta coefficient for operators on manifolds with boundary
# 306772                             A result on the weight distributions of binary quadratic residue codes
# 205892                                     On deformation technique of the hyperbolic secant distribution
# 218358                                                On the minimum order of graphs with given semigroup
# 77078               Meridional trapping and zonal propagation of inertial waves in a rotating fluid shell
# 63150                                                       Two characterizations of the Chern connection
# 422297                                                      On the uniform distribution of numbers mod. 1
# 156367                                      Weak coupling limits in a stochastic model of heat conduction
# 276046                                        Modules over linear spaces admitting a multiplicative basis
# 336155                                Mollified hyperbolic method for coefficient identification problems
# 124871                                       On fundamental transformation groups in the algebra of logic
#
#         MSC_b                                                  MSC2_b  label  \
# 15960   93E03                    ('60J75', '93B36', '93C55', '93C05')    0.0
# 186573  58J20                                      ('35H20', '47D06')    0.0
# 181977  20E22           ('20F16', '20F18', '20E07', '20F14', '20H25')    1.0
# 299961  91A20  ('81P40', '81P45', '91A05', '91A06', '91A12', '91A80')    1.0
# 226982  58J42                                              ('35S15',)    1.0
# 306772  94B35                                              ('94B40',)    1.0
# 205892  60E05                             ('60E10', '62E17', '62E20')    1.0
# 218358  05C99                                      ('05C65', '20M30')    0.0
# 77078   76U05                                      ('76B55', '86A05')    0.0
# 63150   53C10                    ('53A55', '53B05', '58A20', '58A32')    0.0
# 422297  11K06                                              ('11J71',)    0.0
# 156367  82C31                             ('82C35', '60J65', '80A20')    0.0
# 276046  17A60                                      ('17B10', '15A78')    0.0
# 336155  65Z05                             ('65M30', '35R30', '35K15')    0.0
# 124871  03B50                    ('03G20', '20B25', '05A15', '08A35')    1.0
#
#         cosine-sim
# 15960    -0.032483
# 186573    0.156134
# 181977    0.487127
# 299961    0.480388
# 226982    0.230848
# 306772    0.882133
# 205892    0.595832
# 218358    0.558660
# 77078     0.033146
# 63150     0.233177
# 422297    0.202185
# 156367    0.085049
# 276046   -0.113670
# 336155    0.511390
# 124871   -0.010340

# %%
X_test_score[X_test_score["label"]==1].describe()
# Out:
#          label    cosine-sim
# count  21860.0  21860.000000
# mean       1.0      0.600657
# std        0.0      0.281971
# min        1.0     -0.401192
# 25%        1.0      0.391832
# 50%        1.0      0.653625
# 75%        1.0      0.844304
# max        1.0      0.999023

# %%
X_test_score[X_test_score["label"]==0].describe()
# Out:
#          label    cosine-sim
# count  22075.0  22075.000000
# mean       0.0      0.214638
# std        0.0      0.263402
# min        0.0     -0.374664
# 25%        0.0      0.005915
# 50%        0.0      0.159615
# 75%        0.0      0.382822
# max        0.0      0.993558

# %%
X_test_score.sort_values("cosine-sim").head(25)
# Out:
#                                                                                                      title_a  \
# 327880                                                                         Classification of Engel knots
# 128374                                                        Bases for commutator subgroups of a free group
# 434848                                     On the large deviation rates of non-entropy-approachable measures
# 194467                                                           Self-affine fractals and fractal dimension.
# 22361                     Two-dimensional projective linear group and flag-transitive 4-\((v,k,2)\) designs.
# 401101                                                         Differentiation of measures on Hilbert spaces
# 254857                                       Determination of finite plastic deformations in single crystals
# 63463                                                  Finite-type invariants of classical and virtual knots
# 205242                                     Semi-\(g^*\)-closed sets and a new separation axiom in the spaces
# 205397                                                           The Burnside ring of a compact Lie group. I
# 161733      Properties of \(Baire^*\)-1 Darboux functions and some mean value theorems for Peano derivatives
# 162337                                                    Inequalities involving generalized symmetric means
# 149302                                              A new dissimilarity measure for comparing labeled graphs
# 57950                                                    Some non-classical finiteness conditions of modules
# 244804                             Central simple algebras over totally real fields which appear in Q\([G]\)
# 421965  The automorphism group of the semigroup of finite complexes of a rank one torsion free Abelian group
# 55541      New method to obtain periodic solutions of period two and three of a rational difference equation
# 283107                                            The isomorphism relation for separable \(C^\ast\)-algebras
# 81874                                        The fundamental lemma of a relative trace formula for \(GL(3)\)
# 63396                                                               The warping polynomial of a knot diagram
# 363052                              The sliding bifurcations in planar piecewise smooth differential systems
# 176843                           To the theory of nonnegative point Hamiltonians on a plane and in the space
# 305253                    Metastable equilibria of capillary drops on solid surfaces: a phase field approach
# 29996                                                           On the integration of differential fractions
# 152127                                 Flow of variable-viscosity fluid between eccentric rotating cylinders
#
#         MSC_a                                MSC2_a  \
# 327880  53D10                    ('53D15', '57R17')
# 128374  20E05  ('20F05', '20F12', '20E07', '20F14')
# 434848  37C40           ('60F10', '28D20', '37A05')
# 194467  28A80                    ('54F45', '60G20')
# 22361   05B05                            ('20B25',)
# 401101  28C20                            ('28A15',)
# 254857  74C15                    ('74C20', '74E10')
# 63463   57M27                            ('57M25',)
# 205242  54A05           ('54C08', '54C05', '54D10')
# 205397  57S15                    ('22C05', '57S10')
# 161733  26A24                    ('26A15', '26A21')
# 162337  26D15                            ('05A05',)
# 149302  05C50                    ('05C78', '15A18')
# 57950   16D70           ('16P70', '16D90', '16D50')
# 244804  11R52  ('16H05', '16S34', '14F22', '20C15')
# 421965  20M15           ('20B27', '20K15', '20K30')
# 55541   39A10                    ('39A23', '39A30')
# 283107  46L05                    ('37A20', '54H05')
# 81874   11F72  ('11F70', '22E50', '11F46', '11L05')
# 63396   57M27                            ('57M25',)
# 363052  34C23           ('34C37', '34A36', '34C05')
# 176843  47B38                    ('46E35', '47A20')
# 305253  76B45                            ('76D45',)
# 29996   12H05                    ('12Y05', '68W30')
# 152127  76U05                    ('76D05', '80A20')
#
#                                                                                                         title_b  \
# 327880                                                                Riemannian geometry on contact Lie groups
# 128374                                         The complexities of some simple modules of the symmetric groups.
# 434848  Mixed rational-soliton solutions of two differential-difference equations in Casorati determinant form.
# 194467                                                        Fréchet-space-valued measures and the AL-property
# 22361                                                              The distribution of degrees in random graphs
# 401101                                               Covering numbers of different points in Dvoretzky covering
# 254857       On the existence of infinitely many periodic solutions for an equation of a rectangular thin plate
# 63463                                                     On the fundamental group of a compact Kähler manifold
# 205242                                                 Conley index for discrete multi-valued dynamical systems
# 205397                                                   Knots with bounded cusp volume yet large tunnel number
# 161733                                        Some nonlinear delay discrete inequalities and their applications
# 162337                   On the convergence of sequences of functions which are discontinuous on countable sets
# 149302                                                  On multicolour noncomplete Ramsey graphs of star graphs
# 57950                         Commutativity conditions on derivations and Lie ideals in \(\sigma\)-prime rings.
# 244804                              Moment convergence and the law of iterated logarithm for additive functions
# 421965                                              On \(c\)-normal subgroups of some classes of finite groups.
# 55541                                   On some functional equations from additive and non-additive measures. V
# 283107                                                                    A note on sequential weak compactness
# 81874                                                  Diophantine approximation and expansions of real numbers
# 63396                                                      Some continuous decompositions of the space \(E^ n\)
# 363052                                                         Neutral functional equations of the second order
# 176843                                                       Composition operators on summable functions spaces
# 305253                                          Local preconditioners for steady and unsteady flow applications
# 29996                                       Cohomological dimension and Schreier's formula in Galois cohomology
# 152127   Structure and stability of a laminar diffusion flame in a compressible, three-dimensional mixing layer
#
#         MSC_b                                         MSC2_b  label  \
# 327880  53D10           ('53D35', '53C50', '53C25', '57R17')    1.0
# 128374  20C30                             ('20C20', '20C05')    0.0
# 434848  37K40                             ('39A12', '34A05')    0.0
# 194467  28B05  ('46A04', '46A40', '46B42', '46G10', '46B22')    0.0
# 22361   05C80                                     ('05-02',)    0.0
# 401101  28A80                    ('28A78', '60G44', '60G57')    0.0
# 254857  74K20                    ('35B10', '35J05', '35A15')    0.0
# 63463   57R19                                     ('53C55',)    0.0
# 205242  54H20                             ('54C60', '37C80')    0.0
# 205397  57M25                                     ('57M50',)    0.0
# 161733  26D15                                     ('39A10',)    0.0
# 162337  26A15                             ('26A21', '54C05')    0.0
# 149302  05C55                             ('05C70', '05C15')    0.0
# 57950   16W10           ('16W25', '16N60', '16U70', '16U80')    0.0
# 244804  11N60                    ('11K65', '11N37', '60F05')    0.0
# 421965  20D40                             ('20B35', '20D25')    0.0
# 55541   39B62                             ('39B99', '94A17')    0.0
# 283107  46A50                                     ('46A04',)    0.0
# 81874   11J70                    ('11K31', '11J17', '11J72')    0.0
# 63396   57N15                                     ('57N35',)    0.0
# 363052  34K40                             ('34K05', '34K25')    0.0
# 176843  47B38                             ('46E30', '46E35')    1.0
# 305253  76M12                                     ('65M06',)    0.0
# 29996   12G05                                     ('12G10',)    0.0
# 152127  76V05                    ('76E05', '76M20', '80A25')    0.0
#
#         cosine-sim
# 327880   -0.401192
# 128374   -0.374664
# 434848   -0.358477
# 194467   -0.344602
# 22361    -0.344111
# 401101   -0.343002
# 254857   -0.342991
# 63463    -0.342869
# 205242   -0.339679
# 205397   -0.337681
# 161733   -0.334299
# 162337   -0.334243
# 149302   -0.330166
# 57950    -0.329316
# 244804   -0.328936
# 421965   -0.301974
# 55541    -0.301143
# 283107   -0.300662
# 81874    -0.296491
# 63396    -0.292626
# 363052   -0.291711
# 176843   -0.289421
# 305253   -0.289302
# 29996    -0.287658
# 152127   -0.286224

# %%
X_test_score[X_test_score["label"]==1].sort_values("cosine-sim").head(25)
# Out:
#                                                                                                                                           title_a  \
# 308518                                                                    \(C\)-totally real pseudo-parallel submanifolds of Sasakian space forms
# 265436                                                                                            On the class groups of imaginary abelian fields
# 434640                                                                             The coloring of the cozero-divisor graph of a commutative ring
# 199454                                                                                                        Growth functions for Artin monoids.
# 429292                                                                                          Divisors of generic hypersurfaces of general type
# 70499            Modeling, analysis and timetable design of a helicopter maintenance process based on timed event Petri nets and max-plus algebra
# 256760                                                                                 On the use of interval mathematics in fuzzy expert systems
# 356897                                                                                Geometric isomorphism check for symmetric factorial designs
# 333197                                                                                           Calibrations and manifolds with special holonomy
# 282836                                                                              Representation theory of \(U_ 1(H)\) in the symmetric tensors
# 298651                                                                           Classes of matroids closed under minors and principal extensions
# 23645                                                                                     Some properties of a Cayley graph of a commutative ring
# 315472                                                                                          Stratified-algebraic vector bundles of small rank
# 326046                                                                                                       Plastic torsion and related problems
# 385458                                                                       Test ideals in rings with finitely generated anti-canonical algebras
# 90792                                                                                                       Reductions on double occurrence words
# 376387                                                                   Ample vector bundles with zero loci having a hyperelliptic curve section
# 283027                                                                                                             The strict dual of B*-algebras
# 327880                                                                                                              Classification of Engel knots
# 172335                                                 Queues with dependency between interarrival and service times using mixtures of bivariates
# 143033                                                            A new method for solving positive and real systems of linear algebraic equation
# 146959  \(L^ 1\) and \(L^ 2\) properties of a class of singular second order elliptic operators on \(\mathbb{R}^ N\) with measurable coefficients
# 205028                                                                                  Fractal topological analysis for 2D binary digital images
# 63835                                                                                           A totally geodesic property of Hopf vector fields
# 112292                                                                                             Calabi's correspondence and its generalization
#
#         MSC_a                                         MSC2_a  \
# 308518  53B25                             ('53B20', '53B50')
# 265436  11R29                             ('11R20', '11S40')
# 434640  05E40  ('05C15', '05C25', '05C69', '13A70', '16N20')
# 199454  20M05                    ('20F36', '20F05', '17B22')
# 429292  14J70                             ('14C20', '14J29')
# 70499   65F15                                     ('15A80',)
# 256760  68T35                                     ('65G30',)
# 356897  65C60                                     ('65K15',)
# 333197  53C38                                     ('53C29',)
# 282836  46L05                                     ('47D03',)
# 298651  05B35                             ('94A17', '94A24')
# 23645   05C15                    ('05C25', '05C69', '05E30')
# 315472  14P25                    ('14P99', '14J60', '57R22')
# 326046  74K10                             ('74F15', '74K35')
# 385458  14J17                             ('13A35', '14B05')
# 90792   05C90                                     ('92D10',)
# 376387  14J60                    ('14F05', '14N30', '14C20')
# 283027  46L05                                     ('46B10',)
# 327880  53D10                             ('53D15', '57R17')
# 172335  60K20                    ('90B22', '68M20', '62E10')
# 143033  65F10                             ('34A30', '65L05')
# 146959  35Q30                    ('35J15', '76D05', '76N10')
# 205028  54A05           ('54A10', '54D80', '54F65', '54H20')
# 63835   53C40                             ('53C42', '53C20')
# 112292  53C42           ('53A10', '35J60', '53C50', '58J72')
#
#                                                                                                                                      title_b  \
# 308518                                                            Covariant decompositions of symmetric tensors in the theory of gravitation
# 265436                                                                           Some arithmetic properties of generalized Bernoulli numbers
# 434640                                                                                       Laplacian ideals, arrangements, and resolutions
# 199454                                                                            On generalized quaternion groups and the Hadamard matrices
# 429292                                                              Identifiability beyond Kruskal's bound for symmetric tensors of degree 4
# 70499                                                                  Tropical roots as approximations to eigenvalues of matrix polynomials
# 256760                                                           Computing the value of a Boolean expression with interval inputs is NP-hard
# 356897                                        Estimation of arbitrary order central statistical moments by the multilevel Monte Carlo method
# 333197                                                                                Deformations of associative submanifolds with boundary
# 282836                                                                                                    A note on generators of semigroups
# 298651                                                                            The dealer's random bits in perfect secret sharing schemes
# 23645                                                                                                          Acyclic dominating partitions
# 315472                                                                       Codimension two transcendental submanifolds of projective space
# 326046  Active flutter control of a supersonic honeycomb sandwich beam resting on elastic foundation with piezoelectric sensor/actuator pair
# 385458                                                     \(ADE\) bundles over \(ADE\) singular surfaces and flag varieties of \(ADE\) type
# 90792                                                                        DAGmaps: space filling visualization of directed acyclic graphs
# 376387                                                                                          A smooth surface of tame representation type
# 283027                                                                                             Structure in real Banach spaces. I and II
# 327880                                                                                             Riemannian geometry on contact Lie groups
# 172335                                                                                                        Higher-order Lindley equations
# 143033                     A dimensional splitting exponential time differencing scheme for multidimensional fractional Allen-Cahn equations
# 146959   Incompressible limit of all-time solutions to 3-D full Navier-Stokes equations for perfect gas with well-prepared initial condition
# 205028                                                                        Note on generalized topological spaces with hereditary classes
# 63835                                                                                   Biwarped product submanifolds of complex space forms
# 112292                                              Compactness results for immersions of prescribed Gaussian curvature. I: Analytic aspects
#
#         MSC_b  \
# 308518  53B25
# 265436  11R29
# 434640  05E40
# 199454  20M05
# 429292  14J70
# 70499   65F15
# 256760  68T35
# 356897  65C60
# 333197  53C38
# 282836  46L05
# 298651  05B35
# 23645   05C15
# 315472  14P25
# 326046  74K10
# 385458  14J17
# 90792   05C90
# 376387  14J60
# 283027  46L05
# 327880  53D10
# 172335  60K20
# 143033  65F10
# 146959  35Q30
# 205028  54A05
# 63835   53C40
# 112292  53C42
#
#                                                                  MSC2_b  \
# 308518                                      ('53B30', '53B20', '53A45')
# 265436                                               ('11R20', '11B68')
# 434640                             ('05C25', '05C50', '13D02', '52C35')
# 199454                                               ('20F05', '15B57')
# 429292                             ('14C20', '14N05', '15A69', '15A72')
# 70499                              ('15A22', '15A80', '15A12', '65F35')
# 256760                                                       ('65G30',)
# 356897  ('65C05', '65C30', '60H15', '35R60', '65K15', '49J40', '62J10')
# 333197                                      ('35J56', '53C29', '58J32')
# 282836                                               ('47D03', '22A25')
# 298651                                               ('94A60', '94A17')
# 23645                                                        ('05C69',)
# 315472                                               ('57R22', '57R52')
# 326046                                                       ('74F15',)
# 385458                             ('14B05', '14J25', '14J60', '17B05')
# 90792                                                ('05C20', '92D10')
# 376387                                                       ('14F05',)
# 283027                    ('46B10', '46K05', '46E15', '46B99', '46A40')
# 327880                             ('53D35', '53C50', '53C25', '57R17')
# 172335                                               ('60K25', '90B22')
# 143033                                      ('65L05', '65N22', '65F15')
# 146959                    ('35B25', '76M45', '35D35', '76N06', '76D05')
# 205028                                                       ('54A10',)
# 63835                                                ('53C42', '53C30')
# 112292                                      ('53C21', '35J25', '35J60')
#
#         label  cosine-sim
# 308518    1.0   -0.282786
# 265436    1.0   -0.237474
# 434640    1.0   -0.167298
# 199454    1.0   -0.153195
# 429292    1.0   -0.152072
# 70499     1.0   -0.146388
# 256760    1.0   -0.142300
# 356897    1.0   -0.142060
# 333197    1.0   -0.135976
# 282836    1.0   -0.132824
# 298651    1.0   -0.129621
# 23645     1.0   -0.128679
# 315472    1.0   -0.127293
# 326046    1.0   -0.126427
# 385458    1.0   -0.125313
# 90792     1.0   -0.125175
# 376387    1.0   -0.123683
# 283027    1.0   -0.113394
# 327880    1.0   -0.104854
# 172335    1.0   -0.099939
# 143033    1.0   -0.098550
# 146959    1.0   -0.098192
# 205028    1.0   -0.096183
# 63835     1.0   -0.095611
# 112292    1.0   -0.093420

# %%
X_test_score[X_test_score["label"]==0].sort_values("cosine-sim").tail(25)
# Out:
#                                                                                                                             title_a  \
# 41907       The stability analysis of a general viral infection model with distributed delays and multi-staged infected progression
# 202847                                                  Generalized phase retrieval: measurement number, matrix recovery and beyond
# 81023                                                   Bootstrap-based estimates of uncertainty in subspace identification methods
# 231435                                                                     Belief base change operations for answer set programming
# 85208                                  Predator-prey dynamical behavior and stability analysis with square root functional response
# 401173                                                   Vectored injection into compressible laminar and turbulent boundary layers
# 300812  Behavior of upwind scheme in the low Mach number limit. III: Preconditioned dissipation for a five equation two phase model
# 216151                                                                               Disjunctive closures for knowledge compilation
# 368605                                                                        Quantum dynamics in phase space: Moyal trajectories 2
# 149901                                Positive solutions to a Kirchhoff problem with sign-changing and non-Lipschitz nonlinearities
# 286564                                Commutativity of Pfaffianization and Bäcklund transformation: The semi-discrete Toda equation
# 54881                                                          Existence and regularity for elliptic equations under \(p,q\)-growth
# 131005                               Valuing portfolios of interdependent real options under exogenous and endogenous uncertainties
# 75124                                               Nonlinear bending analysis of hyperelastic Mindlin plates: a numerical approach
# 261823                                            Pricing bonds and CDS in the model with rating migration induced by a Cox process
# 241135                                                                   Pricing the constant elasticity of variance trinary option
# 259575                          A \((2+1)\)-dimensional derivative Toda equation in the context of the Kaup-Newell spectral problem
# 137226                                           Existence and uniqueness of the solution for stochastic equations on Banach spaces
# 102786                                                                              Remarks on criteria of prequasi-invex functions
# 243048                                        An analysis of total correctness refinement models for partial relation semantics. II
# 101686                                                                                    On the symmetric difference of fuzzy sets
# 259492                                             Positive solutions for classes of positone problems when a parameter is negative
# 249429                                                                    Optimum symbol-by-symbol mean-square error channel coding
# 197619                                            Choice under risk with certainty and potential effects: a general axiomatic model
# 46383                                                     A key exchange protocol based on Diophantine equations and \(S\)-integers
#
#         MSC_a                                         MSC2_a  \
# 41907   92D25                                     ('37N25',)
# 202847  42C15                    ('94A12', '15A63', '15A83')
# 81023   93B30                                     ('93C41',)
# 231435  68N17                             ('03B42', '68T27')
# 85208   34D20           ('34C60', '34C05', '92D25', '37N25')
# 401173  76N20                    ('76J20', '76D05', '65Z05')
# 300812  76M12                                     ('76G25',)
# 216151  68T30                             ('68Q25', '68T27')
# 368605  81S30  ('53D55', '81S10', '37K10', '83C15', '81Q05')
# 149901  35J20                                     ('35J25',)
# 286564  37K10                             ('37K35', '37K40')
# 54881   35J25                    ('35J62', '35B65', '35D30')
# 131005  91G50                             ('90B50', '90C15')
# 75124   74B20                    ('74K20', '74G65', '65N12')
# 261823  91G40  ('91G80', '60J27', '60K05', '62P05', '91B70')
# 241135  91G20                             ('91B25', '62P05')
# 259575  35Q58                             ('35Q53', '37K10')
# 137226  60H15                                     ('35K05',)
# 102786  90C30                             ('90C26', '90C29')
# 243048  03B70                             ('68Q55', '68Q60')
# 101686  03B52                                     ('03E72',)
# 259492  34B15                                     ('34C23',)
# 249429  94A40                             ('94B05', '94B35')
# 197619  91B06                                     ('91B14',)
# 46383   94A60                                     ('11D99',)
#
#                                                                                                               title_b  \
# 41907                              Dynamical analysis of approximate solutions of HIV-1 model with an arbitrary order
# 202847               Some properties of windowed linear canonical transform and its logarithmic uncertainty principle
# 81023                                         Blind identification using the kurtosis with applications to field data
# 231435                                                  Ordered binary decision diagrams representing knowledge-bases
# 85208                                                          A predator-prey model with Ivlev's functional response
# 401173                            Geometrical structure analysis of a zero-pressure-gradient turbulent boundary layer
# 300812                           A numerical technique for low-speed homogeneous two-phase flow with sharp interfaces
# 216151                                         Reminiscences on the anniversary of 30 years of nonmonotonic reasoning
# 368605                                            Coherent states in fermionic Fock-Krein spaces and their amplitudes
# 149901                    Positive solutions for \(p\)-Laplacian equations of Kirchhoff type problem with a parameter
# 286564                                                           Lie algebras and equations of Korteweg-de Vries type
# 54881                      Liouville type theorems for stable solutions of \(p\)-Laplace equation in \(\mathbb{R}^N\)
# 131005                                                    Hedging with S\&P500 and E-mini S\&P500 stock index futures
# 75124                                Analysis of thin parallelogram plates' bending by the spline-finite-strip method
# 261823                                  Modelling the term structure of interest rates with general short-rate models
# 241135                                                        On theoretical pricing of options with fuzzy estimators
# 259575                                  The quaternionic KP hierarchy and conformally immersed 2-tori in the 4-sphere
# 137226                   Approximation for the solutions of stochastic differential equations. II: Strong convergence
# 102786                             Duality theorems for quasiconvex programming with a reverse quasiconvex constraint
# 243048                                                                  Basic logic: Reflection, symmetry, visibility
# 101686  New uncertainty measure of rough fuzzy sets and entropy weight method for fuzzy-target decision-making tables
# 259492                           Positive solutions for higher order singular nonlinear ordinary differential systems
# 249429                                      Universal coding for memoryless sources with countably infinite alphabets
# 197619                                                 On ``choice'' probabilities derived from ranking distributions
# 46383                          A \((t, n)\) threshold secret sharing system with efficient identification of cheaters
#
#         MSC_b                                MSC2_b  label  cosine-sim
# 41907   92D30                    ('92C60', '34A08')    0.0    0.956253
# 202847  42C40                            ('30G35',)    0.0    0.956792
# 81023   93E11                            ('94A12',)    0.0    0.959381
# 231435  68T30                            ('68T35',)    0.0    0.960011
# 85208   34C05                            ('92D25',)    0.0    0.963358
# 401173  76F40                            ('76F10',)    0.0    0.965251
# 300812  76T99                            ('65Z05',)    0.0    0.966594
# 216151  68T27                            ('68-03',)    0.0    0.967163
# 368605  81R30                    ('30H20', '46C20')    0.0    0.967242
# 149901  35B30           ('35B09', '35J50', '35J62')    0.0    0.967411
# 286564  37L05  ('35Q53', '37K30', '17B67', '37K15')    0.0    0.967928
# 54881   35J60           ('35B53', '35B33', '35B45')    0.0    0.968874
# 131005  91B82                            ('91B28',)    0.0    0.970096
# 75124   74S05                    ('74K20', '74S30')    0.0    0.970583
# 261823  91G30                            ('91B70',)    0.0    0.970844
# 241135  91B28                            ('90C70',)    0.0    0.971681
# 259575  35Q53  ('37K10', '14H70', '53A30', '53C42')    0.0    0.971922
# 137226  60H10                            ('34F05',)    0.0    0.974621
# 102786  90C26                    ('26B25', '49N15')    0.0    0.975159
# 243048  03B20                    ('03B47', '03F05')    0.0    0.975174
# 101686  03E72                    ('91B06', '68T37')    0.0    0.978587
# 259492  34B18                    ('34B16', '47N20')    0.0    0.984368
# 249429  94A24                            ('94A17',)    0.0    0.987638
# 197619  91C99                    ('91B14', '91B08')    0.0    0.989157
# 46383   94A62                    ('68P25', '68W05')    0.0    0.993558
